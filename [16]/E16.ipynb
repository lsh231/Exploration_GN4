# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 프로젝트 : Segmentation map으로 도로 이미지 만들기

# %% [markdown]
# 1. 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해 주세요.
# (어떠한 방법을 사용했는지 적어주세요.)
# 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해 주세요.
# 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
# 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.
# 5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %%
import numpy
import tensorflow

print(numpy.__version__)
print(tensorflow.__version__)
# Out:
# 1.21.6
# 2.8.2

# %%
import os

data_path = '/content/drive/MyDrive/AIFFEL/EXP/data/16Segmentation/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 992

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
  f = data_path + os.listdir(data_path)[np.random.randint(800)]
  print(f)
  img = cv2.imread(f, cv2.IMREAD_COLOR)
  plt.subplot(3,2,i)
  plt.imshow(img)
# Out:
# /content/drive/MyDrive/AIFFEL/EXP/data/16Segmentation/cityscapes/train/257.jpg
# /content/drive/MyDrive/AIFFEL/EXP/data/16Segmentation/cityscapes/train/104.jpg
# /content/drive/MyDrive/AIFFEL/EXP/data/16Segmentation/cityscapes/train/291.jpg
# /content/drive/MyDrive/AIFFEL/EXP/data/16Segmentation/cityscapes/train/992.jpg
# /content/drive/MyDrive/AIFFEL/EXP/data/16Segmentation/cityscapes/train/752.jpg
# /content/drive/MyDrive/AIFFEL/EXP/data/16Segmentation/cityscapes/train/755.jpg

# %% [markdown]
# /content/drive/MyDrive/AIFFEL/EXP/data/16Segmentation/cityscapes/train/에서 /를 안했더니 계속 에러가 나왔다. 별 것 아니지만 꼭 기억을 해두어야 할 부분이다.

# %%
# 이미지 하나 열어 크기 확인

f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
(256, 512, 3)
# (256, 256, 3) 크기의 2개의 이미지로 분할해서 사용합니다.

import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %% [markdown]
# ### Data Augmentation

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])      # 크롭!
    
    out = image.random_flip_left_right(out)                  # 좌우반전!
    out = image.random_flip_up_down(out)                     # 상하반전!
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)        # 90도 회전!
    
    return out[...,:3], out[...,3:]

# %%
# augmentation 적용 후 시각화

plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  encode_block_8 (EncodeBlock)   (None, 128, 128, 64  3072        ['input_2[0][0]']
#                                 )
#
#  encode_block_9 (EncodeBlock)   (None, 64, 64, 128)  131584      ['encode_block_8[0][0]']
#
#  encode_block_10 (EncodeBlock)  (None, 32, 32, 256)  525312      ['encode_block_9[0][0]']
#
#  encode_block_11 (EncodeBlock)  (None, 16, 16, 512)  2099200     ['encode_block_10[0][0]']
#
#  encode_block_12 (EncodeBlock)  (None, 8, 8, 512)    4196352     ['encode_block_11[0][0]']
#
#  encode_block_13 (EncodeBlock)  (None, 4, 4, 512)    4196352     ['encode_block_12[0][0]']
#
#  encode_block_14 (EncodeBlock)  (None, 2, 2, 512)    4196352     ['encode_block_13[0][0]']
#
#  encode_block_15 (EncodeBlock)  (None, 1, 1, 512)    4196352     ['encode_block_14[0][0]']
#
#  decode_block_7 (DecodeBlock)   (None, 2, 2, 512)    4196352     ['encode_block_15[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 2, 2, 1024)   0           ['decode_block_7[0][0]',
#                                                                   'encode_block_14[0][0]']
#
#  decode_block_8 (DecodeBlock)   (None, 4, 4, 512)    8390656     ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 4, 4, 1024)   0           ['decode_block_8[0][0]',
#                                                                   'encode_block_13[0][0]']
#
#  decode_block_9 (DecodeBlock)   (None, 8, 8, 512)    8390656     ['concatenate_8[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 8, 8, 1024)   0           ['decode_block_9[0][0]',
#                                                                   'encode_block_12[0][0]']
#
#  decode_block_10 (DecodeBlock)  (None, 16, 16, 512)  8390656     ['concatenate_9[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 16, 16, 1024  0           ['decode_block_10[0][0]',
#                                 )                                 'encode_block_11[0][0]']
#
#  decode_block_11 (DecodeBlock)  (None, 32, 32, 256)  4195328     ['concatenate_10[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 32, 32, 512)  0           ['decode_block_11[0][0]',
#                                                                   'encode_block_10[0][0]']
#
#  decode_block_12 (DecodeBlock)  (None, 64, 64, 128)  1049088     ['concatenate_11[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 64, 64, 256)  0           ['decode_block_12[0][0]',
#                                                                   'encode_block_9[0][0]']
#
#  decode_block_13 (DecodeBlock)  (None, 128, 128, 64  262400      ['concatenate_12[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 128, 128, 12  0           ['decode_block_13[0][0]',
#                                 8)                                'encode_block_8[0][0]']
#
#  conv2d_transpose_15 (Conv2DTra  (None, 256, 256, 3)  6144       ['concatenate_13[0][0]']
#  nspose)
#
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 32)]    0
#
#  zero_padding2d (ZeroPadding  (None, 130, 130, 32)     0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 127, 127, 64)      32768
#
#  batch_normalization_30 (Bat  (None, 127, 127, 64)     256
#  chNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 127, 127, 64)      0
#
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_5 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  concatenate_14 (Concatenate)   (None, 256, 256, 6)  0           ['input_4[0][0]',
#                                                                   'input_5[0][0]']
#
#  disc_block (DiscBlock)         (None, 128, 128, 64  6144        ['concatenate_14[0][0]']
#                                 )
#
#  disc_block_1 (DiscBlock)       (None, 64, 64, 128)  131584      ['disc_block[0][0]']
#
#  disc_block_2 (DiscBlock)       (None, 32, 32, 256)  525312      ['disc_block_1[0][0]']
#
#  disc_block_3 (DiscBlock)       (None, 31, 31, 512)  2099200     ['disc_block_2[0][0]']
#
#  disc_block_4 (DiscBlock)       (None, 30, 30, 1)    8192        ['disc_block_3[0][0]']
#
#  activation (Activation)        (None, 30, 30, 1)    0           ['disc_block_4[0][0]']
#
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 200

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 100회 반복마다 손실을 출력합니다.
        if (i+1) % 100 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[100]
# Generator_loss:2.8195
# L1_loss:0.2412
# Discriminator_loss:0.9452
#
# EPOCH[1] - STEP[200]
# Generator_loss:2.5824
# L1_loss:0.2329
# Discriminator_loss:0.5070
#
# EPOCH[2] - STEP[100]
# Generator_loss:2.5417
# L1_loss:0.2196
# Discriminator_loss:0.4243
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.3836
# L1_loss:0.1833
# Discriminator_loss:0.4701
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.1795
# L1_loss:0.2173
# Discriminator_loss:0.6858
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.3868
# L1_loss:0.2006
# Discriminator_loss:0.4133
#
# EPOCH[4] - STEP[100]
# Generator_loss:2.1818
# L1_loss:0.1823
# Discriminator_loss:0.3419
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.9984
# L1_loss:0.2143
# Discriminator_loss:0.6995
#
# EPOCH[5] - STEP[100]
# Generator_loss:0.8540
# L1_loss:0.1612
# Discriminator_loss:1.8983
#
# EPOCH[5] - STEP[200]
# Generator_loss:3.3841
# L1_loss:0.1851
# Discriminator_loss:0.6590
#
# EPOCH[6] - STEP[100]
# Generator_loss:2.3306
# L1_loss:0.1830
# Discriminator_loss:0.4678
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.6745
# L1_loss:0.1874
# Discriminator_loss:0.7991
#
# EPOCH[7] - STEP[100]
# Generator_loss:0.4064
# L1_loss:0.1981
# Discriminator_loss:1.3803
#
# EPOCH[7] - STEP[200]
# Generator_loss:3.5953
# L1_loss:0.2160
# Discriminator_loss:1.2640
#
# EPOCH[8] - STEP[100]
# Generator_loss:0.8377
# L1_loss:0.1606
# Discriminator_loss:0.8598
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.6336
# L1_loss:0.2072
# Discriminator_loss:0.6236
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.1221
# L1_loss:0.1422
# Discriminator_loss:0.8938
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.2579
# L1_loss:0.1655
# Discriminator_loss:0.5113
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.5625
# L1_loss:0.1826
# Discriminator_loss:0.2037
#
# EPOCH[10] - STEP[200]
# Generator_loss:0.9964
# L1_loss:0.1880
# Discriminator_loss:0.6248
#
# EPOCH[11] - STEP[100]
# Generator_loss:1.9167
# L1_loss:0.1973
# Discriminator_loss:0.3701
#
# EPOCH[11] - STEP[200]
# Generator_loss:2.2939
# L1_loss:0.1709
# Discriminator_loss:0.3104
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.9898
# L1_loss:0.1962
# Discriminator_loss:0.4085
#
# EPOCH[12] - STEP[200]
# Generator_loss:2.1499
# L1_loss:0.1633
# Discriminator_loss:0.7342
#
# EPOCH[13] - STEP[100]
# Generator_loss:0.9314
# L1_loss:0.1992
# Discriminator_loss:0.8041
#
# EPOCH[13] - STEP[200]
# Generator_loss:2.6529
# L1_loss:0.2023
# Discriminator_loss:0.3516
#
# EPOCH[14] - STEP[100]
# Generator_loss:2.0088
# L1_loss:0.1629
# Discriminator_loss:1.0908
#
# EPOCH[14] - STEP[200]
# Generator_loss:3.8347
# L1_loss:0.2156
# Discriminator_loss:0.9774
#
# EPOCH[15] - STEP[100]
# Generator_loss:2.6213
# L1_loss:0.1347
# Discriminator_loss:0.7187
#
# EPOCH[15] - STEP[200]
# Generator_loss:1.6013
# L1_loss:0.1383
# Discriminator_loss:0.9929
#
# EPOCH[16] - STEP[100]
# Generator_loss:0.6378
# L1_loss:0.1640
# Discriminator_loss:1.2488
#
# EPOCH[16] - STEP[200]
# Generator_loss:3.7137
# L1_loss:0.1725
# Discriminator_loss:0.4855
#
# EPOCH[17] - STEP[100]
# Generator_loss:2.1315
# L1_loss:0.1895
# Discriminator_loss:0.3133
#
# EPOCH[17] - STEP[200]
# Generator_loss:2.0944
# L1_loss:0.1658
# Discriminator_loss:0.3230
#
# EPOCH[18] - STEP[100]
# Generator_loss:1.3209
# L1_loss:0.1550
# Discriminator_loss:0.8772
#
# EPOCH[18] - STEP[200]
# Generator_loss:0.7333
# L1_loss:0.1897
# Discriminator_loss:0.9521
#
# EPOCH[19] - STEP[100]
# Generator_loss:2.0289
# L1_loss:0.1764
# Discriminator_loss:0.2497
#
# EPOCH[19] - STEP[200]
# Generator_loss:2.2234
# L1_loss:0.1495
# Discriminator_loss:0.3316
#
# EPOCH[20] - STEP[100]
# Generator_loss:2.3409
# L1_loss:0.1570
# Discriminator_loss:0.4419
#
# EPOCH[20] - STEP[200]
# Generator_loss:2.2853
# L1_loss:0.1607
# Discriminator_loss:0.6630
#
# EPOCH[21] - STEP[100]
# Generator_loss:1.8909
# L1_loss:0.1449
# Discriminator_loss:0.3461
#
# EPOCH[21] - STEP[200]
# Generator_loss:1.4225
# L1_loss:0.1667
# Discriminator_loss:0.5675
#
# EPOCH[22] - STEP[100]
# Generator_loss:1.1287
# L1_loss:0.1640
# Discriminator_loss:0.7948
#
# EPOCH[22] - STEP[200]
# Generator_loss:1.7720
# L1_loss:0.1565
# Discriminator_loss:0.4767
#
# EPOCH[23] - STEP[100]
# Generator_loss:1.7941
# L1_loss:0.1620
# Discriminator_loss:0.3415
#
# EPOCH[23] - STEP[200]
# Generator_loss:2.9383
# L1_loss:0.1632
# Discriminator_loss:0.4826
#
# EPOCH[24] - STEP[100]
# Generator_loss:2.6728
# L1_loss:0.1568
# Discriminator_loss:1.6514
#
# EPOCH[24] - STEP[200]
# Generator_loss:4.0956
# L1_loss:0.1661
# Discriminator_loss:0.1736
#
# EPOCH[25] - STEP[100]
# Generator_loss:0.8455
# L1_loss:0.2246
# Discriminator_loss:0.7339
#
# EPOCH[25] - STEP[200]
# Generator_loss:1.1412
# L1_loss:0.1547
# Discriminator_loss:0.6581
#
# EPOCH[26] - STEP[100]
# Generator_loss:2.8467
# L1_loss:0.1214
# Discriminator_loss:0.4581
#
# EPOCH[26] - STEP[200]
# Generator_loss:2.5137
# L1_loss:0.2133
# Discriminator_loss:0.1385
#
# EPOCH[27] - STEP[100]
# Generator_loss:2.8778
# L1_loss:0.1658
# Discriminator_loss:0.5345
#
# EPOCH[27] - STEP[200]
# Generator_loss:3.0575
# L1_loss:0.1699
# Discriminator_loss:0.2574
#
# EPOCH[28] - STEP[100]
# Generator_loss:4.2430
# L1_loss:0.1333
# Discriminator_loss:2.1880
#
# EPOCH[28] - STEP[200]
# Generator_loss:0.8391
# L1_loss:0.1443
# Discriminator_loss:0.8940
#
# EPOCH[29] - STEP[100]
# Generator_loss:1.0428
# L1_loss:0.1750
# Discriminator_loss:0.9432
#
# EPOCH[29] - STEP[200]
# Generator_loss:1.0929
# L1_loss:0.1382
# Discriminator_loss:0.5806
#
# EPOCH[30] - STEP[100]
# Generator_loss:2.7292
# L1_loss:0.1642
# Discriminator_loss:0.7150
#
# EPOCH[30] - STEP[200]
# Generator_loss:2.6892
# L1_loss:0.1532
# Discriminator_loss:0.3929
#
# EPOCH[31] - STEP[100]
# Generator_loss:2.2250
# L1_loss:0.1576
# Discriminator_loss:0.5912
#
# EPOCH[31] - STEP[200]
# Generator_loss:3.6418
# L1_loss:0.1537
# Discriminator_loss:0.2637
#
# EPOCH[32] - STEP[100]
# Generator_loss:2.0999
# L1_loss:0.1407
# Discriminator_loss:0.4783
#
# EPOCH[32] - STEP[200]
# Generator_loss:2.4052
# L1_loss:0.1218
# Discriminator_loss:1.5007
#
# EPOCH[33] - STEP[100]
# Generator_loss:2.8640
# L1_loss:0.1296
# Discriminator_loss:0.4787
#
# EPOCH[33] - STEP[200]
# Generator_loss:3.1280
# L1_loss:0.1774
# Discriminator_loss:0.6025
#
# EPOCH[34] - STEP[100]
# Generator_loss:1.1250
# L1_loss:0.1558
# Discriminator_loss:0.9191
#
# EPOCH[34] - STEP[200]
# Generator_loss:3.0969
# L1_loss:0.1638
# Discriminator_loss:0.1484
#
# EPOCH[35] - STEP[100]
# Generator_loss:4.0082
# L1_loss:0.1529
# Discriminator_loss:0.2769
#
# EPOCH[35] - STEP[200]
# Generator_loss:2.7088
# L1_loss:0.1401
# Discriminator_loss:0.8339
#
# EPOCH[36] - STEP[100]
# Generator_loss:1.3169
# L1_loss:0.1661
# Discriminator_loss:0.5501
#
# EPOCH[36] - STEP[200]
# Generator_loss:3.0164
# L1_loss:0.1343
# Discriminator_loss:0.4092
#
# EPOCH[37] - STEP[100]
# Generator_loss:2.4480
# L1_loss:0.1591
# Discriminator_loss:0.4014
#
# EPOCH[37] - STEP[200]
# Generator_loss:2.9441
# L1_loss:0.1326
# Discriminator_loss:0.8875
#
# EPOCH[38] - STEP[100]
# Generator_loss:1.6881
# L1_loss:0.1307
# Discriminator_loss:0.4383
#
# EPOCH[38] - STEP[200]
# Generator_loss:2.1967
# L1_loss:0.1373
# Discriminator_loss:1.1017
#
# EPOCH[39] - STEP[100]
# Generator_loss:1.9109
# L1_loss:0.1883
# Discriminator_loss:0.3095
#
# EPOCH[39] - STEP[200]
# Generator_loss:2.5624
# L1_loss:0.1438
# Discriminator_loss:0.3659
#
# EPOCH[40] - STEP[100]
# Generator_loss:2.8465
# L1_loss:0.1604
# Discriminator_loss:0.1261
#
# EPOCH[40] - STEP[200]
# Generator_loss:2.0460
# L1_loss:0.2149
# Discriminator_loss:0.2074
#
# EPOCH[41] - STEP[100]
# Generator_loss:1.9706
# L1_loss:0.1328
# Discriminator_loss:0.3733
#
# EPOCH[41] - STEP[200]
# Generator_loss:1.2288
# L1_loss:0.1238
# Discriminator_loss:0.6121
#
# EPOCH[42] - STEP[100]
# Generator_loss:2.3680
# L1_loss:0.1281
# Discriminator_loss:0.5045
#
# EPOCH[42] - STEP[200]
# Generator_loss:2.3833
# L1_loss:0.1558
# Discriminator_loss:0.2443
#
# EPOCH[43] - STEP[100]
# Generator_loss:3.2717
# L1_loss:0.1913
# Discriminator_loss:0.3549
#
# EPOCH[43] - STEP[200]
# Generator_loss:3.3407
# L1_loss:0.1418
# Discriminator_loss:1.9883
#
# EPOCH[44] - STEP[100]
# Generator_loss:3.6745
# L1_loss:0.1334
# Discriminator_loss:1.3842
#
# EPOCH[44] - STEP[200]
# Generator_loss:1.3565
# L1_loss:0.1572
# Discriminator_loss:0.4517
#
# EPOCH[45] - STEP[100]
# Generator_loss:2.6999
# L1_loss:0.1368
# Discriminator_loss:0.2531
#
# EPOCH[45] - STEP[200]
# Generator_loss:2.7215
# L1_loss:0.1486
# Discriminator_loss:0.2953
#
# EPOCH[46] - STEP[100]
# Generator_loss:2.2111
# L1_loss:0.1655
# Discriminator_loss:0.2701
#
# EPOCH[46] - STEP[200]
# Generator_loss:1.7996
# L1_loss:0.1465
# Discriminator_loss:0.3238
#
# EPOCH[47] - STEP[100]
# Generator_loss:2.8118
# L1_loss:0.1370
# Discriminator_loss:0.2569
#
# EPOCH[47] - STEP[200]
# Generator_loss:3.4947
# L1_loss:0.1641
# Discriminator_loss:0.0700
#
# EPOCH[48] - STEP[100]
# Generator_loss:2.6574
# L1_loss:0.1421
# Discriminator_loss:0.4524
#
# EPOCH[48] - STEP[200]
# Generator_loss:4.9362
# L1_loss:0.1386
# Discriminator_loss:0.3318
#
# EPOCH[49] - STEP[100]
# Generator_loss:3.1074
# L1_loss:0.1575
# Discriminator_loss:0.6804
#
# EPOCH[49] - STEP[200]
# Generator_loss:3.6492
# L1_loss:0.1684
# Discriminator_loss:0.3836
#
# EPOCH[50] - STEP[100]
# Generator_loss:3.4621
# L1_loss:0.1057
# Discriminator_loss:1.1670
#
# EPOCH[50] - STEP[200]
# Generator_loss:2.1416
# L1_loss:0.1602
# Discriminator_loss:0.4381
#
# EPOCH[51] - STEP[100]
# Generator_loss:2.6088
# L1_loss:0.1168
# Discriminator_loss:1.5901
#
# EPOCH[51] - STEP[200]
# Generator_loss:1.4623
# L1_loss:0.1773
# Discriminator_loss:0.5024
#
# EPOCH[52] - STEP[100]
# Generator_loss:4.6094
# L1_loss:0.1535
# Discriminator_loss:0.8402
#
# EPOCH[52] - STEP[200]
# Generator_loss:2.9934
# L1_loss:0.1151
# Discriminator_loss:0.3379
#
# EPOCH[53] - STEP[100]
# Generator_loss:2.1162
# L1_loss:0.1425
# Discriminator_loss:0.3370
#
# EPOCH[53] - STEP[200]
# Generator_loss:1.5545
# L1_loss:0.1334
# Discriminator_loss:0.7845
#
# EPOCH[54] - STEP[100]
# Generator_loss:5.3506
# L1_loss:0.1367
# Discriminator_loss:0.5446
#
# EPOCH[54] - STEP[200]
# Generator_loss:1.3507
# L1_loss:0.1525
# Discriminator_loss:0.7305
#
# EPOCH[55] - STEP[100]
# Generator_loss:4.9870
# L1_loss:0.1308
# Discriminator_loss:1.1148
#
# EPOCH[55] - STEP[200]
# Generator_loss:1.4875
# L1_loss:0.1346
# Discriminator_loss:0.5221
#
# EPOCH[56] - STEP[100]
# Generator_loss:2.7845
# L1_loss:0.1779
# Discriminator_loss:0.2286
#
# EPOCH[56] - STEP[200]
# Generator_loss:3.5253
# L1_loss:0.1640
# Discriminator_loss:0.7145
#
# EPOCH[57] - STEP[100]
# Generator_loss:1.8630
# L1_loss:0.1480
# Discriminator_loss:0.2894
#
# EPOCH[57] - STEP[200]
# Generator_loss:1.6732
# L1_loss:0.1316
# Discriminator_loss:0.3807
#
# EPOCH[58] - STEP[100]
# Generator_loss:0.7987
# L1_loss:0.1465
# Discriminator_loss:0.9413
#
# EPOCH[58] - STEP[200]
# Generator_loss:3.2036
# L1_loss:0.1345
# Discriminator_loss:0.1724
#
# EPOCH[59] - STEP[100]
# Generator_loss:2.2978
# L1_loss:0.1439
# Discriminator_loss:0.2171
#
# EPOCH[59] - STEP[200]
# Generator_loss:4.7477
# L1_loss:0.1199
# Discriminator_loss:0.8625
#
# EPOCH[60] - STEP[100]
# Generator_loss:2.4984
# L1_loss:0.1531
# Discriminator_loss:0.1707
#
# EPOCH[60] - STEP[200]
# Generator_loss:2.4546
# L1_loss:0.1411
# Discriminator_loss:0.5212
#
# EPOCH[61] - STEP[100]
# Generator_loss:6.0819
# L1_loss:0.1468
# Discriminator_loss:0.9517
#
# EPOCH[61] - STEP[200]
# Generator_loss:2.2922
# L1_loss:0.1285
# Discriminator_loss:0.2295
#
# EPOCH[62] - STEP[100]
# Generator_loss:4.0936
# L1_loss:0.1537
# Discriminator_loss:1.3333
#
# EPOCH[62] - STEP[200]
# Generator_loss:3.9300
# L1_loss:0.1079
# Discriminator_loss:0.4698
#
# EPOCH[63] - STEP[100]
# Generator_loss:3.1604
# L1_loss:0.1242
# Discriminator_loss:0.7248
#
# EPOCH[63] - STEP[200]
# Generator_loss:2.1341
# L1_loss:0.1336
# Discriminator_loss:0.4529
#
# EPOCH[64] - STEP[100]
# Generator_loss:4.5108
# L1_loss:0.1464
# Discriminator_loss:0.2811
#
# EPOCH[64] - STEP[200]
# Generator_loss:3.0820
# L1_loss:0.1258
# Discriminator_loss:0.1839
#
# EPOCH[65] - STEP[100]
# Generator_loss:1.9988
# L1_loss:0.1491
# Discriminator_loss:0.2392
#
# EPOCH[65] - STEP[200]
# Generator_loss:1.6891
# L1_loss:0.1590
# Discriminator_loss:0.3838
#
# EPOCH[66] - STEP[100]
# Generator_loss:1.5058
# L1_loss:0.1370
# Discriminator_loss:0.4697
#
# EPOCH[66] - STEP[200]
# Generator_loss:2.3931
# L1_loss:0.1249
# Discriminator_loss:0.3398
#
# EPOCH[67] - STEP[100]
# Generator_loss:1.5631
# L1_loss:0.1716
# Discriminator_loss:0.3986
#
# EPOCH[67] - STEP[200]
# Generator_loss:6.2142
# L1_loss:0.1295
# Discriminator_loss:1.1684
#
# EPOCH[68] - STEP[100]
# Generator_loss:0.9086
# L1_loss:0.1919
# Discriminator_loss:0.9100
#
# EPOCH[68] - STEP[200]
# Generator_loss:2.0179
# L1_loss:0.1286
# Discriminator_loss:0.3416
#
# EPOCH[69] - STEP[100]
# Generator_loss:5.2245
# L1_loss:0.1318
# Discriminator_loss:0.1759
#
# EPOCH[69] - STEP[200]
# Generator_loss:2.0422
# L1_loss:0.1058
# Discriminator_loss:0.7387
#
# EPOCH[70] - STEP[100]
# Generator_loss:3.0180
# L1_loss:0.1455
# Discriminator_loss:0.1255
#
# EPOCH[70] - STEP[200]
# Generator_loss:0.4111
# L1_loss:0.1413
# Discriminator_loss:1.7991
#
# EPOCH[71] - STEP[100]
# Generator_loss:3.6634
# L1_loss:0.1485
# Discriminator_loss:0.0577
#
# EPOCH[71] - STEP[200]
# Generator_loss:1.5860
# L1_loss:0.1279
# Discriminator_loss:0.5328
#
# EPOCH[72] - STEP[100]
# Generator_loss:1.2368
# L1_loss:0.1392
# Discriminator_loss:0.6083
#
# EPOCH[72] - STEP[200]
# Generator_loss:4.6813
# L1_loss:0.1339
# Discriminator_loss:0.1416
#
# EPOCH[73] - STEP[100]
# Generator_loss:0.7257
# L1_loss:0.1387
# Discriminator_loss:0.9432
#
# EPOCH[73] - STEP[200]
# Generator_loss:1.2613
# L1_loss:0.1238
# Discriminator_loss:0.7553
#
# EPOCH[74] - STEP[100]
# Generator_loss:3.5427
# L1_loss:0.1351
# Discriminator_loss:0.4362
#
# EPOCH[74] - STEP[200]
# Generator_loss:3.5329
# L1_loss:0.1589
# Discriminator_loss:0.1242
#
# EPOCH[75] - STEP[100]
# Generator_loss:3.1561
# L1_loss:0.1304
# Discriminator_loss:0.1015
#
# EPOCH[75] - STEP[200]
# Generator_loss:4.1654
# L1_loss:0.1506
# Discriminator_loss:0.3709
#
# EPOCH[76] - STEP[100]
# Generator_loss:5.3819
# L1_loss:0.1616
# Discriminator_loss:0.0960
#
# EPOCH[76] - STEP[200]
# Generator_loss:1.9105
# L1_loss:0.1390
# Discriminator_loss:0.3008
#
# EPOCH[77] - STEP[100]
# Generator_loss:2.7781
# L1_loss:0.1237
# Discriminator_loss:0.1779
#
# EPOCH[77] - STEP[200]
# Generator_loss:2.8502
# L1_loss:0.1521
# Discriminator_loss:0.2262
#
# EPOCH[78] - STEP[100]
# Generator_loss:3.0687
# L1_loss:0.1522
# Discriminator_loss:0.1549
#
# EPOCH[78] - STEP[200]
# Generator_loss:0.6142
# L1_loss:0.1220
# Discriminator_loss:1.1988
#
# EPOCH[79] - STEP[100]
# Generator_loss:2.1025
# L1_loss:0.1176
# Discriminator_loss:0.3276
#
# EPOCH[79] - STEP[200]
# Generator_loss:3.8343
# L1_loss:0.1412
# Discriminator_loss:0.5143
#
# EPOCH[80] - STEP[100]
# Generator_loss:2.4123
# L1_loss:0.1583
# Discriminator_loss:0.2988
#
# EPOCH[80] - STEP[200]
# Generator_loss:2.4681
# L1_loss:0.1490
# Discriminator_loss:0.2063
#
# EPOCH[81] - STEP[100]
# Generator_loss:3.2839
# L1_loss:0.1138
# Discriminator_loss:0.2547
#
# EPOCH[81] - STEP[200]
# Generator_loss:2.3833
# L1_loss:0.1382
# Discriminator_loss:0.3025
#
# EPOCH[82] - STEP[100]
# Generator_loss:3.6318
# L1_loss:0.1300
# Discriminator_loss:0.2049
#
# EPOCH[82] - STEP[200]
# Generator_loss:4.6073
# L1_loss:0.1424
# Discriminator_loss:0.1504
#
# EPOCH[83] - STEP[100]
# Generator_loss:2.1848
# L1_loss:0.1395
# Discriminator_loss:0.5782
#
# EPOCH[83] - STEP[200]
# Generator_loss:2.9440
# L1_loss:0.1093
# Discriminator_loss:0.2454
#
# EPOCH[84] - STEP[100]
# Generator_loss:3.5607
# L1_loss:0.1180
# Discriminator_loss:0.5470
#
# EPOCH[84] - STEP[200]
# Generator_loss:5.1798
# L1_loss:0.1491
# Discriminator_loss:0.2013
#
# EPOCH[85] - STEP[100]
# Generator_loss:6.2717
# L1_loss:0.1173
# Discriminator_loss:1.1669
#
# EPOCH[85] - STEP[200]
# Generator_loss:4.5817
# L1_loss:0.1002
# Discriminator_loss:0.7644
#
# EPOCH[86] - STEP[100]
# Generator_loss:4.7657
# L1_loss:0.1337
# Discriminator_loss:0.4799
#
# EPOCH[86] - STEP[200]
# Generator_loss:2.0239
# L1_loss:0.1627
# Discriminator_loss:0.3064
#
# EPOCH[87] - STEP[100]
# Generator_loss:2.6139
# L1_loss:0.1102
# Discriminator_loss:0.5982
#
# EPOCH[87] - STEP[200]
# Generator_loss:1.6530
# L1_loss:0.1570
# Discriminator_loss:0.5152
#
# EPOCH[88] - STEP[100]
# Generator_loss:3.6794
# L1_loss:0.1644
# Discriminator_loss:0.0967
#
# EPOCH[88] - STEP[200]
# Generator_loss:2.2115
# L1_loss:0.1223
# Discriminator_loss:1.0025
#
# EPOCH[89] - STEP[100]
# Generator_loss:1.8541
# L1_loss:0.1283
# Discriminator_loss:0.8092
#
# EPOCH[89] - STEP[200]
# Generator_loss:5.7502
# L1_loss:0.1293
# Discriminator_loss:0.2519
#
# EPOCH[90] - STEP[100]
# Generator_loss:3.5316
# L1_loss:0.1414
# Discriminator_loss:0.1508
#
# EPOCH[90] - STEP[200]
# Generator_loss:3.8658
# L1_loss:0.1167
# Discriminator_loss:0.5364
#
# EPOCH[91] - STEP[100]
# Generator_loss:2.0667
# L1_loss:0.1178
# Discriminator_loss:0.2852
#
# EPOCH[91] - STEP[200]
# Generator_loss:3.9943
# L1_loss:0.1485
# Discriminator_loss:0.1191
#
# EPOCH[92] - STEP[100]
# Generator_loss:3.8307
# L1_loss:0.1432
# Discriminator_loss:0.0814
#
# EPOCH[92] - STEP[200]
# Generator_loss:3.1848
# L1_loss:0.1376
# Discriminator_loss:0.5047
#
# EPOCH[93] - STEP[100]
# Generator_loss:0.9361
# L1_loss:0.1258
# Discriminator_loss:0.8493
#
# EPOCH[93] - STEP[200]
# Generator_loss:4.0623
# L1_loss:0.1490
# Discriminator_loss:0.0869
#
# EPOCH[94] - STEP[100]
# Generator_loss:3.3723
# L1_loss:0.1686
# Discriminator_loss:0.4433
#
# EPOCH[94] - STEP[200]
# Generator_loss:0.9049
# L1_loss:0.1783
# Discriminator_loss:0.9234
#
# EPOCH[95] - STEP[100]
# Generator_loss:5.5572
# L1_loss:0.0998
# Discriminator_loss:0.5308
#
# EPOCH[95] - STEP[200]
# Generator_loss:1.1792
# L1_loss:0.1183
# Discriminator_loss:0.6602
#
# EPOCH[96] - STEP[100]
# Generator_loss:3.1847
# L1_loss:0.1214
# Discriminator_loss:0.2487
#
# EPOCH[96] - STEP[200]
# Generator_loss:4.8656
# L1_loss:0.1541
# Discriminator_loss:0.0225
#
# EPOCH[97] - STEP[100]
# Generator_loss:1.8652
# L1_loss:0.1231
# Discriminator_loss:0.3533
#
# EPOCH[97] - STEP[200]
# Generator_loss:5.3560
# L1_loss:0.1461
# Discriminator_loss:0.1089
#
# EPOCH[98] - STEP[100]
# Generator_loss:2.4211
# L1_loss:0.1206
# Discriminator_loss:0.5367
#
# EPOCH[98] - STEP[200]
# Generator_loss:3.3391
# L1_loss:0.1088
# Discriminator_loss:0.1200
#
# EPOCH[99] - STEP[100]
# Generator_loss:3.1172
# L1_loss:0.1176
# Discriminator_loss:0.5885
#
# EPOCH[99] - STEP[200]
# Generator_loss:3.8684
# L1_loss:0.1181
# Discriminator_loss:0.0822
#
# EPOCH[100] - STEP[100]
# Generator_loss:0.9022
# L1_loss:0.1366
# Discriminator_loss:0.8649
#
# EPOCH[100] - STEP[200]
# Generator_loss:2.8892
# L1_loss:0.1314
# Discriminator_loss:0.1215
#
# EPOCH[101] - STEP[100]
# Generator_loss:3.3191
# L1_loss:0.1618
# Discriminator_loss:0.0969
#
# EPOCH[101] - STEP[200]
# Generator_loss:2.5042
# L1_loss:0.1147
# Discriminator_loss:0.3271
#
# EPOCH[102] - STEP[100]
# Generator_loss:3.8728
# L1_loss:0.1287
# Discriminator_loss:0.1758
#
# EPOCH[102] - STEP[200]
# Generator_loss:5.3905
# L1_loss:0.1327
# Discriminator_loss:1.1727
#
# EPOCH[103] - STEP[100]
# Generator_loss:2.2630
# L1_loss:0.1136
# Discriminator_loss:0.2514
#
# EPOCH[103] - STEP[200]
# Generator_loss:5.0647
# L1_loss:0.1113
# Discriminator_loss:0.9669
#
# EPOCH[104] - STEP[100]
# Generator_loss:0.7362
# L1_loss:0.1207
# Discriminator_loss:0.9064
#
# EPOCH[104] - STEP[200]
# Generator_loss:2.8446
# L1_loss:0.1777
# Discriminator_loss:0.2591
#
# EPOCH[105] - STEP[100]
# Generator_loss:4.5823
# L1_loss:0.1133
# Discriminator_loss:0.2678
#
# EPOCH[105] - STEP[200]
# Generator_loss:4.5012
# L1_loss:0.1486
# Discriminator_loss:0.0575
#
# EPOCH[106] - STEP[100]
# Generator_loss:3.8491
# L1_loss:0.1385
# Discriminator_loss:0.0820
#
# EPOCH[106] - STEP[200]
# Generator_loss:2.5583
# L1_loss:0.1229
# Discriminator_loss:0.3124
#
# EPOCH[107] - STEP[100]
# Generator_loss:2.9140
# L1_loss:0.1370
# Discriminator_loss:0.3562
#
# EPOCH[107] - STEP[200]
# Generator_loss:4.3216
# L1_loss:0.1171
# Discriminator_loss:0.3717
#
# EPOCH[108] - STEP[100]
# Generator_loss:0.9393
# L1_loss:0.1166
# Discriminator_loss:0.8620
#
# EPOCH[108] - STEP[200]
# Generator_loss:4.6664
# L1_loss:0.1619
# Discriminator_loss:0.0371
#
# EPOCH[109] - STEP[100]
# Generator_loss:5.5201
# L1_loss:0.1243
# Discriminator_loss:0.2813
#
# EPOCH[109] - STEP[200]
# Generator_loss:6.7638
# L1_loss:0.1305
# Discriminator_loss:0.8551
#
# EPOCH[110] - STEP[100]
# Generator_loss:4.4074
# L1_loss:0.1160
# Discriminator_loss:0.4393
#
# EPOCH[110] - STEP[200]
# Generator_loss:2.7845
# L1_loss:0.1131
# Discriminator_loss:0.2853
#
# EPOCH[111] - STEP[100]
# Generator_loss:0.7712
# L1_loss:0.1264
# Discriminator_loss:0.9639
#
# EPOCH[111] - STEP[200]
# Generator_loss:1.3440
# L1_loss:0.1015
# Discriminator_loss:0.6392
#
# EPOCH[112] - STEP[100]
# Generator_loss:3.5255
# L1_loss:0.1253
# Discriminator_loss:0.2088
#
# EPOCH[112] - STEP[200]
# Generator_loss:0.5840
# L1_loss:0.1591
# Discriminator_loss:1.5489
#
# EPOCH[113] - STEP[100]
# Generator_loss:4.0974
# L1_loss:0.1131
# Discriminator_loss:0.1468
#
# EPOCH[113] - STEP[200]
# Generator_loss:3.2727
# L1_loss:0.1344
# Discriminator_loss:0.1953
#
# EPOCH[114] - STEP[100]
# Generator_loss:1.0693
# L1_loss:0.1040
# Discriminator_loss:0.6968
#
# EPOCH[114] - STEP[200]
# Generator_loss:4.0425
# L1_loss:0.1139
# Discriminator_loss:0.0839
#
# EPOCH[115] - STEP[100]
# Generator_loss:3.2066
# L1_loss:0.1290
# Discriminator_loss:0.1437
#
# EPOCH[115] - STEP[200]
# Generator_loss:3.9722
# L1_loss:0.1591
# Discriminator_loss:0.0796
#
# EPOCH[116] - STEP[100]
# Generator_loss:4.3154
# L1_loss:0.1302
# Discriminator_loss:0.1305
#
# EPOCH[116] - STEP[200]
# Generator_loss:0.7178
# L1_loss:0.1343
# Discriminator_loss:1.0357
#
# EPOCH[117] - STEP[100]
# Generator_loss:1.7137
# L1_loss:0.1023
# Discriminator_loss:0.8253
#
# EPOCH[117] - STEP[200]
# Generator_loss:3.6160
# L1_loss:0.1772
# Discriminator_loss:0.0589
#
# EPOCH[118] - STEP[100]
# Generator_loss:3.4483
# L1_loss:0.1157
# Discriminator_loss:0.1455
#
# EPOCH[118] - STEP[200]
# Generator_loss:5.1581
# L1_loss:0.1797
# Discriminator_loss:0.0255
#
# EPOCH[119] - STEP[100]
# Generator_loss:2.4723
# L1_loss:0.1146
# Discriminator_loss:0.3426
#
# EPOCH[119] - STEP[200]
# Generator_loss:5.5451
# L1_loss:0.1257
# Discriminator_loss:0.2036
#
# EPOCH[120] - STEP[100]
# Generator_loss:2.0909
# L1_loss:0.1228
# Discriminator_loss:0.3771
#
# EPOCH[120] - STEP[200]
# Generator_loss:4.1621
# L1_loss:0.1260
# Discriminator_loss:0.2188
#
# EPOCH[121] - STEP[100]
# Generator_loss:2.7440
# L1_loss:0.1298
# Discriminator_loss:0.2218
#
# EPOCH[121] - STEP[200]
# Generator_loss:2.0693
# L1_loss:0.1236
# Discriminator_loss:1.0133
#
# EPOCH[122] - STEP[100]
# Generator_loss:6.2555
# L1_loss:0.0940
# Discriminator_loss:0.5176
#
# EPOCH[122] - STEP[200]
# Generator_loss:1.7952
# L1_loss:0.1336
# Discriminator_loss:0.4152
#
# EPOCH[123] - STEP[100]
# Generator_loss:4.4368
# L1_loss:0.1286
# Discriminator_loss:0.5550
#
# EPOCH[123] - STEP[200]
# Generator_loss:2.2104
# L1_loss:0.1189
# Discriminator_loss:0.2143
#
# EPOCH[124] - STEP[100]
# Generator_loss:2.9283
# L1_loss:0.1178
# Discriminator_loss:0.1472
#
# EPOCH[124] - STEP[200]
# Generator_loss:4.7814
# L1_loss:0.1365
# Discriminator_loss:0.0966
#
# EPOCH[125] - STEP[100]
# Generator_loss:2.4170
# L1_loss:0.1839
# Discriminator_loss:0.4423
#
# EPOCH[125] - STEP[200]
# Generator_loss:5.1932
# L1_loss:0.1193
# Discriminator_loss:0.3813
#
# EPOCH[126] - STEP[100]
# Generator_loss:3.0497
# L1_loss:0.1216
# Discriminator_loss:0.2764
#
# EPOCH[126] - STEP[200]
# Generator_loss:2.0251
# L1_loss:0.1392
# Discriminator_loss:0.2623
#
# EPOCH[127] - STEP[100]
# Generator_loss:6.2750
# L1_loss:0.1384
# Discriminator_loss:0.1071
#
# EPOCH[127] - STEP[200]
# Generator_loss:3.0096
# L1_loss:0.1180
# Discriminator_loss:0.3795
#
# EPOCH[128] - STEP[100]
# Generator_loss:6.1585
# L1_loss:0.1046
# Discriminator_loss:1.0117
#
# EPOCH[128] - STEP[200]
# Generator_loss:5.1112
# L1_loss:0.1000
# Discriminator_loss:2.1958
#
# EPOCH[129] - STEP[100]
# Generator_loss:2.4246
# L1_loss:0.1348
# Discriminator_loss:0.2112
#
# EPOCH[129] - STEP[200]
# Generator_loss:5.2862
# L1_loss:0.1031
# Discriminator_loss:1.1461
#
# EPOCH[130] - STEP[100]
# Generator_loss:1.6911
# L1_loss:0.1059
# Discriminator_loss:0.9080
#
# EPOCH[130] - STEP[200]
# Generator_loss:4.5718
# L1_loss:0.1290
# Discriminator_loss:0.0586
#
# EPOCH[131] - STEP[100]
# Generator_loss:3.9527
# L1_loss:0.1360
# Discriminator_loss:0.0411
#
# EPOCH[131] - STEP[200]
# Generator_loss:2.6409
# L1_loss:0.1438
# Discriminator_loss:0.1752
#
# EPOCH[132] - STEP[100]
# Generator_loss:2.9375
# L1_loss:0.1227
# Discriminator_loss:0.2391
#
# EPOCH[132] - STEP[200]
# Generator_loss:2.4232
# L1_loss:0.1261
# Discriminator_loss:0.4763
#
# EPOCH[133] - STEP[100]
# Generator_loss:1.6233
# L1_loss:0.1333
# Discriminator_loss:0.5920
#
# EPOCH[133] - STEP[200]
# Generator_loss:5.1709
# L1_loss:0.1052
# Discriminator_loss:0.0334
#
# EPOCH[134] - STEP[100]
# Generator_loss:2.5937
# L1_loss:0.1184
# Discriminator_loss:0.2592
#
# EPOCH[134] - STEP[200]
# Generator_loss:4.7510
# L1_loss:0.1326
# Discriminator_loss:0.1850
#
# EPOCH[135] - STEP[100]
# Generator_loss:5.2692
# L1_loss:0.0997
# Discriminator_loss:1.6039
#
# EPOCH[135] - STEP[200]
# Generator_loss:2.0108
# L1_loss:0.1470
# Discriminator_loss:0.3613
#
# EPOCH[136] - STEP[100]
# Generator_loss:2.5528
# L1_loss:0.1441
# Discriminator_loss:0.2719
#
# EPOCH[136] - STEP[200]
# Generator_loss:4.5065
# L1_loss:0.1284
# Discriminator_loss:0.0828
#
# EPOCH[137] - STEP[100]
# Generator_loss:2.9339
# L1_loss:0.1141
# Discriminator_loss:0.3805
#
# EPOCH[137] - STEP[200]
# Generator_loss:4.4656
# L1_loss:0.1468
# Discriminator_loss:0.0884
#
# EPOCH[138] - STEP[100]
# Generator_loss:4.1233
# L1_loss:0.1102
# Discriminator_loss:0.9360
#
# EPOCH[138] - STEP[200]
# Generator_loss:2.5313
# L1_loss:0.1423
# Discriminator_loss:0.2340
#
# EPOCH[139] - STEP[100]
# Generator_loss:6.0539
# L1_loss:0.1304
# Discriminator_loss:0.2187
#
# EPOCH[139] - STEP[200]
# Generator_loss:6.1051
# L1_loss:0.1395
# Discriminator_loss:0.0078
#
# EPOCH[140] - STEP[100]
# Generator_loss:4.7376
# L1_loss:0.1392
# Discriminator_loss:0.0213
#
# EPOCH[140] - STEP[200]
# Generator_loss:3.5120
# L1_loss:0.1285
# Discriminator_loss:0.2118
#
# EPOCH[141] - STEP[100]
# Generator_loss:3.2346
# L1_loss:0.1274
# Discriminator_loss:0.1786
#
# EPOCH[141] - STEP[200]
# Generator_loss:6.9029
# L1_loss:0.1425
# Discriminator_loss:0.4833
#
# EPOCH[142] - STEP[100]
# Generator_loss:4.1174
# L1_loss:0.1481
# Discriminator_loss:0.1483
#
# EPOCH[142] - STEP[200]
# Generator_loss:3.5422
# L1_loss:0.1117
# Discriminator_loss:0.5005
#
# EPOCH[143] - STEP[100]
# Generator_loss:3.8080
# L1_loss:0.1256
# Discriminator_loss:0.2695
#
# EPOCH[143] - STEP[200]
# Generator_loss:2.4689
# L1_loss:0.1149
# Discriminator_loss:0.2393
#
# EPOCH[144] - STEP[100]
# Generator_loss:2.0145
# L1_loss:0.1003
# Discriminator_loss:0.3002
#
# EPOCH[144] - STEP[200]
# Generator_loss:3.2857
# L1_loss:0.1673
# Discriminator_loss:0.2612
#
# EPOCH[145] - STEP[100]
# Generator_loss:3.4702
# L1_loss:0.1166
# Discriminator_loss:0.2401
#
# EPOCH[145] - STEP[200]
# Generator_loss:3.5011
# L1_loss:0.1303
# Discriminator_loss:0.1323
#
# EPOCH[146] - STEP[100]
# Generator_loss:3.5452
# L1_loss:0.1472
# Discriminator_loss:0.0754
#
# EPOCH[146] - STEP[200]
# Generator_loss:3.9159
# L1_loss:0.1006
# Discriminator_loss:1.0996
#
# EPOCH[147] - STEP[100]
# Generator_loss:2.2832
# L1_loss:0.1286
# Discriminator_loss:0.3132
#
# EPOCH[147] - STEP[200]
# Generator_loss:5.5291
# L1_loss:0.1235
# Discriminator_loss:0.0209
#
# EPOCH[148] - STEP[100]
# Generator_loss:2.7316
# L1_loss:0.1125
# Discriminator_loss:0.1786
#
# EPOCH[148] - STEP[200]
# Generator_loss:0.6037
# L1_loss:0.1005
# Discriminator_loss:1.1996
#
# EPOCH[149] - STEP[100]
# Generator_loss:2.7703
# L1_loss:0.1387
# Discriminator_loss:0.1722
#
# EPOCH[149] - STEP[200]
# Generator_loss:3.0221
# L1_loss:0.1099
# Discriminator_loss:0.1792
#
# EPOCH[150] - STEP[100]
# Generator_loss:2.3783
# L1_loss:0.1472
# Discriminator_loss:0.4850
#
# EPOCH[150] - STEP[200]
# Generator_loss:5.0550
# L1_loss:0.1439
# Discriminator_loss:0.0825
#
# EPOCH[151] - STEP[100]
# Generator_loss:2.6654
# L1_loss:0.1015
# Discriminator_loss:0.5439
#
# EPOCH[151] - STEP[200]
# Generator_loss:1.3635
# L1_loss:0.1645
# Discriminator_loss:0.4527
#
# EPOCH[152] - STEP[100]
# Generator_loss:2.1631
# L1_loss:0.1138
# Discriminator_loss:0.8377
#
# EPOCH[152] - STEP[200]
# Generator_loss:5.8284
# L1_loss:0.1162
# Discriminator_loss:0.0218
#
# EPOCH[153] - STEP[100]
# Generator_loss:2.8048
# L1_loss:0.1392
# Discriminator_loss:0.4349
#
# EPOCH[153] - STEP[200]
# Generator_loss:2.1449
# L1_loss:0.1029
# Discriminator_loss:0.2437
#
# EPOCH[154] - STEP[100]
# Generator_loss:1.6085
# L1_loss:0.1128
# Discriminator_loss:0.4414
#
# EPOCH[154] - STEP[200]
# Generator_loss:5.9247
# L1_loss:0.1305
# Discriminator_loss:0.9318
#
# EPOCH[155] - STEP[100]
# Generator_loss:3.2038
# L1_loss:0.1706
# Discriminator_loss:0.0945
#
# EPOCH[155] - STEP[200]
# Generator_loss:7.5310
# L1_loss:0.1272
# Discriminator_loss:0.1653
#
# EPOCH[156] - STEP[100]
# Generator_loss:0.5897
# L1_loss:0.1608
# Discriminator_loss:1.2898
#
# EPOCH[156] - STEP[200]
# Generator_loss:4.6199
# L1_loss:0.1620
# Discriminator_loss:0.0290
#
# EPOCH[157] - STEP[100]
# Generator_loss:3.5855
# L1_loss:0.1042
# Discriminator_loss:0.7817
#
# EPOCH[157] - STEP[200]
# Generator_loss:2.8948
# L1_loss:0.1110
# Discriminator_loss:0.2859
#
# EPOCH[158] - STEP[100]
# Generator_loss:2.5134
# L1_loss:0.1095
# Discriminator_loss:1.4157
#
# EPOCH[158] - STEP[200]
# Generator_loss:1.5648
# L1_loss:0.1064
# Discriminator_loss:0.4788
#
# EPOCH[159] - STEP[100]
# Generator_loss:1.6406
# L1_loss:0.1058
# Discriminator_loss:0.5242
#
# EPOCH[159] - STEP[200]
# Generator_loss:2.6623
# L1_loss:0.1373
# Discriminator_loss:0.1343
#
# EPOCH[160] - STEP[100]
# Generator_loss:2.7027
# L1_loss:0.1209
# Discriminator_loss:0.1653
#
# EPOCH[160] - STEP[200]
# Generator_loss:4.1634
# L1_loss:0.1022
# Discriminator_loss:0.0680
#
# EPOCH[161] - STEP[100]
# Generator_loss:1.8202
# L1_loss:0.1131
# Discriminator_loss:0.3942
#
# EPOCH[161] - STEP[200]
# Generator_loss:2.0335
# L1_loss:0.1281
# Discriminator_loss:0.2795
#
# EPOCH[162] - STEP[100]
# Generator_loss:5.4489
# L1_loss:0.1140
# Discriminator_loss:0.0892
#
# EPOCH[162] - STEP[200]
# Generator_loss:4.9116
# L1_loss:0.1112
# Discriminator_loss:0.1512
#
# EPOCH[163] - STEP[100]
# Generator_loss:2.5194
# L1_loss:0.1105
# Discriminator_loss:0.1662
#
# EPOCH[163] - STEP[200]
# Generator_loss:3.9384
# L1_loss:0.1280
# Discriminator_loss:0.1308
#
# EPOCH[164] - STEP[100]
# Generator_loss:5.9852
# L1_loss:0.1293
# Discriminator_loss:0.0956
#
# EPOCH[164] - STEP[200]
# Generator_loss:2.2633
# L1_loss:0.0941
# Discriminator_loss:0.3828
#
# EPOCH[165] - STEP[100]
# Generator_loss:5.6928
# L1_loss:0.1191
# Discriminator_loss:0.9037
#
# EPOCH[165] - STEP[200]
# Generator_loss:5.1693
# L1_loss:0.1218
# Discriminator_loss:0.0361
#
# EPOCH[166] - STEP[100]
# Generator_loss:2.6879
# L1_loss:0.1284
# Discriminator_loss:0.1760
#
# EPOCH[166] - STEP[200]
# Generator_loss:5.4309
# L1_loss:0.1266
# Discriminator_loss:0.4626
#
# EPOCH[167] - STEP[100]
# Generator_loss:1.7129
# L1_loss:0.1090
# Discriminator_loss:0.3891
#
# EPOCH[167] - STEP[200]
# Generator_loss:3.5308
# L1_loss:0.1020
# Discriminator_loss:0.2168
#
# EPOCH[168] - STEP[100]
# Generator_loss:0.3350
# L1_loss:0.1288
# Discriminator_loss:2.5132
#
# EPOCH[168] - STEP[200]
# Generator_loss:4.7196
# L1_loss:0.1266
# Discriminator_loss:0.1131
#
# EPOCH[169] - STEP[100]
# Generator_loss:5.6421
# L1_loss:0.1547
# Discriminator_loss:0.0473
#
# EPOCH[169] - STEP[200]
# Generator_loss:2.6970
# L1_loss:0.1089
# Discriminator_loss:0.1533
#
# EPOCH[170] - STEP[100]
# Generator_loss:3.1159
# L1_loss:0.1352
# Discriminator_loss:0.1078
#
# EPOCH[170] - STEP[200]
# Generator_loss:6.7549
# L1_loss:0.1451
# Discriminator_loss:0.0224
#
# EPOCH[171] - STEP[100]
# Generator_loss:6.4912
# L1_loss:0.1136
# Discriminator_loss:0.1610
#
# EPOCH[171] - STEP[200]
# Generator_loss:5.4866
# L1_loss:0.1218
# Discriminator_loss:0.0259
#
# EPOCH[172] - STEP[100]
# Generator_loss:1.5414
# L1_loss:0.1178
# Discriminator_loss:0.4860
#
# EPOCH[172] - STEP[200]
# Generator_loss:1.6680
# L1_loss:0.1464
# Discriminator_loss:0.4492
#
# EPOCH[173] - STEP[100]
# Generator_loss:2.2130
# L1_loss:0.1005
# Discriminator_loss:0.2429
#
# EPOCH[173] - STEP[200]
# Generator_loss:6.0693
# L1_loss:0.1300
# Discriminator_loss:0.0381
#
# EPOCH[174] - STEP[100]
# Generator_loss:4.1904
# L1_loss:0.1058
# Discriminator_loss:0.1189
#
# EPOCH[174] - STEP[200]
# Generator_loss:6.2086
# L1_loss:0.1397
# Discriminator_loss:0.0068
#
# EPOCH[175] - STEP[100]
# Generator_loss:3.8634
# L1_loss:0.1133
# Discriminator_loss:0.5003
#
# EPOCH[175] - STEP[200]
# Generator_loss:5.6732
# L1_loss:0.1140
# Discriminator_loss:0.1982
#
# EPOCH[176] - STEP[100]
# Generator_loss:4.1131
# L1_loss:0.1312
# Discriminator_loss:0.0706
#
# EPOCH[176] - STEP[200]
# Generator_loss:3.3390
# L1_loss:0.1401
# Discriminator_loss:0.0926
#
# EPOCH[177] - STEP[100]
# Generator_loss:6.0645
# L1_loss:0.1112
# Discriminator_loss:0.0689
#
# EPOCH[177] - STEP[200]
# Generator_loss:6.0763
# L1_loss:0.1058
# Discriminator_loss:0.0317
#
# EPOCH[178] - STEP[100]
# Generator_loss:1.3514
# L1_loss:0.0947
# Discriminator_loss:1.1721
#
# EPOCH[178] - STEP[200]
# Generator_loss:4.3281
# L1_loss:0.1431
# Discriminator_loss:0.2445
#
# EPOCH[179] - STEP[100]
# Generator_loss:2.0220
# L1_loss:0.0989
# Discriminator_loss:0.6520
#
# EPOCH[179] - STEP[200]
# Generator_loss:4.0546
# L1_loss:0.1194
# Discriminator_loss:0.2218
#
# EPOCH[180] - STEP[100]
# Generator_loss:8.6362
# L1_loss:0.1101
# Discriminator_loss:0.7052
#
# EPOCH[180] - STEP[200]
# Generator_loss:1.2930
# L1_loss:0.1079
# Discriminator_loss:0.6639
#
# EPOCH[181] - STEP[100]
# Generator_loss:1.4132
# L1_loss:0.1117
# Discriminator_loss:0.5730
#
# EPOCH[181] - STEP[200]
# Generator_loss:5.3039
# L1_loss:0.1392
# Discriminator_loss:0.0366
#
# EPOCH[182] - STEP[100]
# Generator_loss:5.5193
# L1_loss:0.1206
# Discriminator_loss:0.0520
#
# EPOCH[182] - STEP[200]
# Generator_loss:2.9979
# L1_loss:0.1098
# Discriminator_loss:0.6257
#
# EPOCH[183] - STEP[100]
# Generator_loss:5.5824
# L1_loss:0.1140
# Discriminator_loss:1.9049
#
# EPOCH[183] - STEP[200]
# Generator_loss:5.6966
# L1_loss:0.1339
# Discriminator_loss:0.0560
#
# EPOCH[184] - STEP[100]
# Generator_loss:3.4599
# L1_loss:0.1218
# Discriminator_loss:0.2118
#
# EPOCH[184] - STEP[200]
# Generator_loss:5.5861
# L1_loss:0.1160
# Discriminator_loss:0.4462
#
# EPOCH[185] - STEP[100]
# Generator_loss:4.4494
# L1_loss:0.1079
# Discriminator_loss:0.0459
#
# EPOCH[185] - STEP[200]
# Generator_loss:1.6265
# L1_loss:0.1152
# Discriminator_loss:0.5840
#
# EPOCH[186] - STEP[100]
# Generator_loss:2.7778
# L1_loss:0.1316
# Discriminator_loss:0.1900
#
# EPOCH[186] - STEP[200]
# Generator_loss:1.1421
# L1_loss:0.1184
# Discriminator_loss:0.8749
#
# EPOCH[187] - STEP[100]
# Generator_loss:5.5914
# L1_loss:0.1096
# Discriminator_loss:0.2845
#
# EPOCH[187] - STEP[200]
# Generator_loss:3.5906
# L1_loss:0.1168
# Discriminator_loss:0.0951
#
# EPOCH[188] - STEP[100]
# Generator_loss:6.0876
# L1_loss:0.1177
# Discriminator_loss:0.0906
#
# EPOCH[188] - STEP[200]
# Generator_loss:4.6796
# L1_loss:0.1255
# Discriminator_loss:0.0248
#
# EPOCH[189] - STEP[100]
# Generator_loss:5.8889
# L1_loss:0.1431
# Discriminator_loss:0.3668
#
# EPOCH[189] - STEP[200]
# Generator_loss:4.0341
# L1_loss:0.1200
# Discriminator_loss:0.1470
#
# EPOCH[190] - STEP[100]
# Generator_loss:1.1512
# L1_loss:0.1193
# Discriminator_loss:0.6704
#
# EPOCH[190] - STEP[200]
# Generator_loss:1.6735
# L1_loss:0.1349
# Discriminator_loss:0.5245
#
# EPOCH[191] - STEP[100]
# Generator_loss:4.6063
# L1_loss:0.1309
# Discriminator_loss:0.0295
#
# EPOCH[191] - STEP[200]
# Generator_loss:6.7028
# L1_loss:0.1857
# Discriminator_loss:0.0064
#
# EPOCH[192] - STEP[100]
# Generator_loss:5.2826
# L1_loss:0.1019
# Discriminator_loss:0.5929
#
# EPOCH[192] - STEP[200]
# Generator_loss:3.2803
# L1_loss:0.1918
# Discriminator_loss:0.0686
#
# EPOCH[193] - STEP[100]
# Generator_loss:5.4438
# L1_loss:0.1026
# Discriminator_loss:0.0621
#
# EPOCH[193] - STEP[200]
# Generator_loss:3.4886
# L1_loss:0.0878
# Discriminator_loss:0.3546
#
# EPOCH[194] - STEP[100]
# Generator_loss:3.5896
# L1_loss:0.1133
# Discriminator_loss:0.1469
#
# EPOCH[194] - STEP[200]
# Generator_loss:6.1812
# L1_loss:0.1034
# Discriminator_loss:0.5090
#
# EPOCH[195] - STEP[100]
# Generator_loss:7.4238
# L1_loss:0.1357
# Discriminator_loss:0.1100
#
# EPOCH[195] - STEP[200]
# Generator_loss:6.2404
# L1_loss:0.1125
# Discriminator_loss:0.0481
#
# EPOCH[196] - STEP[100]
# Generator_loss:5.7847
# L1_loss:0.1377
# Discriminator_loss:0.0160
#
# EPOCH[196] - STEP[200]
# Generator_loss:7.7288
# L1_loss:0.1264
# Discriminator_loss:0.4281
#
# EPOCH[197] - STEP[100]
# Generator_loss:0.6411
# L1_loss:0.1058
# Discriminator_loss:1.2358
#
# EPOCH[197] - STEP[200]
# Generator_loss:4.0472
# L1_loss:0.1259
# Discriminator_loss:0.0462
#
# EPOCH[198] - STEP[100]
# Generator_loss:5.4966
# L1_loss:0.0983
# Discriminator_loss:0.2312
#
# EPOCH[198] - STEP[200]
# Generator_loss:2.3619
# L1_loss:0.1334
# Discriminator_loss:0.3262
#
# EPOCH[199] - STEP[100]
# Generator_loss:4.9710
# L1_loss:0.1018
# Discriminator_loss:0.0667
#
# EPOCH[199] - STEP[200]
# Generator_loss:3.8295
# L1_loss:0.1321
# Discriminator_loss:0.1069
#
# EPOCH[200] - STEP[100]
# Generator_loss:2.0267
# L1_loss:0.1220
# Discriminator_loss:0.2682
#
# EPOCH[200] - STEP[200]
# Generator_loss:3.1265
# L1_loss:0.1137
# Discriminator_loss:0.0863

# %%
EPOCHS = 200
fig = plt.figure(figsize=(13,4))
g = []
l1 = []
d = []

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
    g.append(g_loss.numpy())
    l1.append(l1_loss.numpy())
    d.append(d_loss.numpy())

epochs = range(1, len(g)+1)

ax1 = fig.add_subplot(1,3,1)
plt.plot(epochs, g, 'r', label='Generator loss')
plt.title('Generator loss')
plt.xlabel('Epochs')
plt.ylabel('g_Loss')
plt.legend()

ax2 = fig.add_subplot(1,3,2)
plt.plot(epochs, l1, 'y', label='L1 loss')
plt.title('L1 loss')
plt.xlabel('Epochs')
plt.ylabel('L1_Loss')
plt.legend()

ax3 = fig.add_subplot(1,3,3)
plt.plot(epochs, d, 'b', label='Discriminator loss')
plt.title('Discriminator loss')
plt.xlabel('Epochs')
plt.ylabel('d_Loss')
plt.legend()

# %%
test_ind = 2
val_path = '/content/drive/MyDrive/AIFFEL/EXP/data/16Segmentation/cityscapes/val'

f = data_path + os.listdir(val_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# 회고
#
# 1. pix2pix 방법으로 이미지를 생성하였다. 좀 더 비슷한 이미지를 만들기 위해 U-net 모델을 사용하고 손실함수를 L1+cGAN를 선택하였다.
# 2. 저번 GAN노드에서는 epoch을 늘려지만 손실이나 정확도는 큰변화가 없었지만 이 노드에서 변화가 있었다.
